# %%
from facebook_scraper import get_posts

import pandas as pd

posts=get_posts("vermeg", pages=100)



p=pd.DataFrame(posts)


p.to_csv("porshe.csv",index=False)

# %%
p
# Out:
#      comments                                              image  likes  \
# 0           1  https://external.ftun12-1.fna.fbcdn.net/safe_i...      5
# 1           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     11
# 2           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     27
# 3           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     21
# 4           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...      5
# 5           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...      8
# 6           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...      6
# 7           0  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     27
# 8          18  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     55
# 9           8  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     89
# 10         28  https://scontent.ftun12-1.fna.fbcdn.net/v/t1.0...     77
# 11          0                                               None      7
# ...

# %%
ch=''
for e in p.post_text:
    ch+=e

# %%
ch
# Out:
# 'VERMEG is Awarded Gold Certification for its Commitment to Sustainable Development by EcoVadis, and is now Top 5% of Most Advanced Companies Recognized for Corporate Social Responsibility.\n… Morehttps://www.vermeg.com/news-resources,vermeg-awarded-gold-certification-for-its-commitment-to-sustainable-development-,49.html\n#VERMEG #RSE #sustainableworldLive from the 5th edition of Insurance Revolution event, in Madrid. VERMEG for Banking & Insurance Software is glad to be a sponsor at the reference event of the Insurance Industry in Spain.\n#VERMEG #Insurancesolutions #DigitalecosystemsVERMEG\'s anniversary celebration in Tunis office.\nWe are delighted to honor your commitment, as you are our greatest asset.\nIt is with great pride and admiration that we celebrate theses milestones. We look forward with great expectancy to many more good years to celebrate all of you.Meet us at Sibos 2019 in London !\nVERMEG will be attending the Sibos 2019 Conference on the 23rd-26th of September.\
# ...

# %%
import re
def clean_tweet(tweet):
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
ch=clean_tweet(ch)

# %%
tokens = [t for t in ch.split()]
print(tokens)
# Out:
# ['VERMEG', 'is', 'Awarded', 'Gold', 'Certification', 'for', 'its', 'Commitment', 'to', 'Sustainable', 'Development', 'by', 'EcoVadis', 'and', 'is', 'now', 'Top', '5', 'of', 'Most', 'Advanced', 'Companies', 'Recognized', 'for', 'Corporate', 'Social', 'Responsibility', 'VERMEG', 'RSE', 'sustainableworldLive', 'from', 'the', '5th', 'edition', 'of', 'Insurance', 'Revolution', 'event', 'in', 'Madrid', 'VERMEG', 'for', 'Banking', 'Insurance', 'Software', 'is', 'glad', 'to', 'be', 'a', 'sponsor', 'at', 'the', 'reference', 'event', 'of', 'the', 'Insurance', 'Industry', 'in', 'Spain', 'VERMEG', 'Insurancesolutions', 'DigitalecosystemsVERMEG', 's', 'anniversary', 'celebration', 'in', 'Tunis', 'office', 'We', 'are', 'delighted', 'to', 'honor', 'your', 'commitment', 'as', 'you', 'are', 'our', 'greatest', 'asset', 'It', 'is', 'with', 'great', 'pride', 'and', 'admiration', 'that', 'we', 'celebrate', 'theses', 'milestones', 'We', 'look', 'forward', 'with', 'great', 'expectancy', 'to', 'many', 'more
# ...

# %%
import nltk
from nltk.corpus import stopwords
sr= stopwords.words('english')
clean_tokens = tokens[:]
for token in tokens:
    ##Creating a list of custom stopwords
    new_words = ["using", "show", "large", "also", "iv", "one", "two", "new", "previously", "shown","The","le","pr","e","r","les","la","5"]
    sr = sr+new_words
    if token in sr:
        clean_tokens.remove(token)
for token in clean_tokens:
    if token in stopwords.words('french'):
        clean_tokens.remove(token)
freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
freq.plot(20, cumulative=False)
# Out:
# VERMEG:31
# Awarded:2
# Gold:1
# Certification:2
# Commitment:1
# Sustainable:1
# Development:1
# EcoVadis:1
# Top:2
# Most:1
# Advanced:1
# Companies:1
# Recognized:1
# Corporate:8
# Social:1
# Responsibility:1
# RSE:1
# sustainableworldLive:1
# 5th:2
# edition:7
# Insurance:13
# Revolution:1
# event:9
# Madrid:1
# Banking:11
# Software:9
# glad:3
# sponsor:1
# reference:1
# Industry:1
# Spain:3
# Insurancesolutions:1
# DigitalecosystemsVERMEG:1
# anniversary:1
# celebration:1
# Tunis:13
# office:2
# We:6
# delighted:2
# honor:2
# commitment:4
# greatest:2
# asset:12
# It:2
# great:9
# pride:2
# admiration:2
# celebrate:4
# theses:1
# milestones:2
# look:3
# forward:6
# expectancy:2
# many:2
# good:2
# years:3
# Meet:1
# us:12
# Sibos:5
# 2019:7
# London:2
# attending:2
# Conference:2
# 23rd:1
# 26th:1
# September:3
# Our:2
# team:4
# experts:7
# present:4
# latest:4
# products:4
# Digital:4
# More:41
# Transformation:4
# sectors:1
# You:2
# book:1
# meeting:6
# Looking:3
# SIBOS:2
# ...

# %%
# %matplotlib qt
