# %% [raw]
# #Twitter API mots de passe
#     consumer_key = "oPhDXAWRU2IllBkcB9aPXVTxL"
#     consumer_secret = "QukVI2doUQWuYVO3taVW7wo6i9aeP5CBOUGk1KsLDGGljw9yj1"
#     access_key = "2387496134-Fvypze4AeON63ylfz2uI14gvqyOg5JKIL7dbdRz"
#     access_secret = "wQpc7SwZAgy46dVtOIJVPyV5s1Mqn71CWQWZFqHE4VsO0"
#
#     OAUTH_KEYS = {'consumer_key':consumer_key, 'consumer_secret':consumer_secret,
#      'access_token_key':access_key, 'access_token_secret':access_secret}
#     auth = tweepy.OAuthHandler(OAUTH_KEYS['consumer_key'], OAUTH_KEYS['consumer_secret'])
#     api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
#Twitter API mots de passe
consumer_key = "IDaHS6WGO62ITPeU848JSr09O"
consumer_secret = "oH3ApicDEWSmfEKQHbtuBjWVV0VVWRJ2Q1ZFoFhzdNR3tASaG0"
access_key = "1106543187735257088-8Qo7Hz8YRye8mwpxqFxQpPslGL7QtR"
access_secret = "9F9U2ACenzTSKz0TKEmwGuZ6scWKi6KKoFKIWtNdHPbWk"

# %%
def get_tweets(entreprise_name):
    
    

#search = api.user_timeline(screen_name="realDonaldTrump",count=200)
    search = tweepy.Cursor(api.search, q='#'+entreprise_name.lower().strip()).items(400) # ici on spécifie le mot clé

# Creation des listes pour chaque tweet
    sn = []
    text = []
    timestamp =[]
    st=[]
    keywords = ['excellent', 'milliards', 'mexico']
    for tweet in search:
      #if any(keyword in tweet.text for keyword in keywords):
        #print (tweet.text)
        clean_tweet(tweet.text)
        timestamp.append(tweet.created_at)
        sn.append(tweet.user.screen_name)
        text.append(tweet.text)
        st.append(analize_sentiment(tweet.text))         
# Converstion des listes vers des dataframe (objet pandas)
    df = pd.DataFrame()
    df['timestamp'] = timestamp
    df['sn'] = sn
    df['text'] = text
    df['sentiment']=st

# Pour décaler les temps par rapport à l'heure locale aux états unis
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df['EST'] = df['timestamp'] - pd.Timedelta(hours=5)

    df['EST'] = pd.to_datetime(df['EST'])
    df.to_csv('trumptweet.csv',index = False,encoding='utf-8')
    allNames = list(df['sn'].unique())


    dfUsers = pd.DataFrame()
    dfUsers['userFromName'] =[]
    dfUsers['userFromId'] =[]
    dfUsers['userToId'] = []
    count = 0
    pos_tweets = [ tweet for index, tweet in enumerate(df['text']) if df['sentiment'][index] > 0]

    return len(pos_tweets)*100/len(df['text'])

# %%
import re
import tweepy
import csv
import pandas as pd
from textblob import TextBlob

# pour l'interaction avec l'utilisateur
import time
import sys
def clean_tweet(tweet):
    
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
import time

print("Printed immediately.")
time.sleep(2.4)
print("Printed immediately.")
# Out:
# Printed immediately.
# Printed immediately.

# %%
for i in range(0,500):
    if CV["company_name"][i]=="Vide":
        continue
    liste=str(CV["company_name"][i]).strip("[]").strip("").replace('"', '').replace("'","")
    print(liste.split(","))
    for j in range(len(liste)):
        if len(liste[j])==1:
            #percentage=get_tweets(liste[j])
        else:
            #percentage=get_tweets(liste[j].split()[0])
        newdf["Company"][i]=liste[j]
        newdf["rate"][i]=percentage
# Out:
# ['Ubuntu Tunisie']
# C:\Users\a_mir\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\a_mir\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-41-f14f6ef4a8de> in <module>
#       6     for j in range(len(liste)):
#       7         if len(liste[j])==1:
# ...

# %%
newdf=pd.DataFrame(0, index=np.arange(len(CV)), columns=("Company","rate"))

# %%
list(CV["company_name"])
# Out:
# ['Vide',
#  'Vide',
#  "[['Ubuntu Tunisie']]",
#  "[['Ubuntu Tunisie']]",
#  "[['Business&Decision Tunisie']]",
#  "[['Business&Decision Tunisie']]",
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  'Vide',
#  "[['Bank ABC']]",
#  "[['Bank ABC']]",
#  "[['Focus Corporation', 'Ooredoo Tunisie', 'Ooredoo Tunisie']]",
#  "[['Focus Corporation', 'Ooredoo Tunisie', 'Ooredoo Tunisie']]",
#  "[['Crédit Agricole CIB', 'SNCF', 'Heppner']]",
#  "[['Crédit Agricole CIB', 'SNCF', 'Heppner']]",
#  "[['universite']]",
#  "[['universite']]",
#  "[['Mentor Graphics', 'FIS', 'SAGEMCOM']]",
#  "[['Mentor Graphics', 'FIS', 'SAGEMCOM']]",
#  "[['Extia', 'FIS', 'ADACTIM', 'skytechnology']]",
#  "[['Extia', 'FIS', 'ADACTIM', 'skytechnology']]",
#  "[['Vermeg', 'BFI']]",
#  "[['Vermeg', 'BFI']]",
#  "[['Talan Tunisie', 'Talan', 'Pharmaghreb', 'MELKART Junior Entreprise', 'Groupe Chimique Tunisien']]",
# ...

# %%
[['SOAT', 'OYEZ', 'Upperskills', 'Digit-U', 'Pixels Trade']]",

# %%
ch="GRDF"
res1=get_tweets(ch)
newdf["Company"][31]=ch
newdf["rate"][31]=res1
# Out:
# C:\Users\a_mir\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\a_mir\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
newdf1=newdf.sort_values(by=['rate'],ascending=False)
newdf1 = newdf1.reset_index(drop=True)

# %%
newdf1.head(30)
# Out:
#               Company  rate
# 0           instadeep    87
# 1            WebScale    80
# 2            Bee Soft    75
# 3   Business&Decision    68
# 4          New Access    49
# 5                 SAP    46
# 6                 IBM    45
# 7      Ubuntu Tunisie    34
# 8    Bouygues Telecom    33
# 9                SONY    33
# 10             Telnet    31
# 11             Orange    30
# 12            SAMSUNG    30
# 13               ASML    30
# 14         IP-Systems    28
# 15                ATB    27
# 16            Renault    26
# 17                HLi    25
# 18       eXo Platform    19
# 19              Total    19
# 20            Essilor    19
# 21             Altran    15
# 22             ENEDIS    15
# 23            Ooredoo    13
# 24          Carrefour    11
# 25             Sogeti     8
# 26              Talan     8
# 27               GRDF     4
# 28              tecos     3
# 29              sopra     2
